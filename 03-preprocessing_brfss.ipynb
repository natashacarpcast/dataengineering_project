# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.set_option('display.max_columns', None)

# %%
brfss = pd.read_csv("data/BRFSS2023.csv", index_col=0)

# %%
brfss
# Out:
#         _STATE  SEXVAR  _AGEG5YR  EDUCA  INCOME3  _RACE  BPHIGH6  DIABETE4  \
# 0            1       2        13    5.0     99.0    1.0      1.0       1.0
# 1            1       2        13    5.0     99.0    1.0      1.0       3.0
# 2            1       2        13    4.0      2.0    2.0      1.0       3.0
# 3            1       2        12    5.0     99.0    1.0      3.0       3.0
# 4            1       2        12    5.0      7.0    1.0      1.0       1.0
# ...        ...     ...       ...    ...      ...    ...      ...       ...
# 433318      78       1        10    5.0      5.0    2.0      1.0       3.0
# 433319      78       2         3    6.0      6.0    2.0      3.0       3.0
# 433320      78       2         7    6.0     10.0    8.0      3.0       3.0
# 433321      78       2        10    6.0      3.0    2.0      1.0       1.0
# 433322      78       1         6    2.0      2.0    2.0      3.0       3.0
#
#         CVDINFR4  CVDCRHD4  CVDSTRK3  SMOKE100  SMOKDAY2  EXERANY2   _BMI5  \
# 0            2.0       2.0       2.0       2.0       NaN       2.0  3047.0
# 1            2.0       2.0       2.0       2.0       NaN       1.0  2856.0
# 2            2.0       2.0       2.0       1.0       3.0       1.0  2231.0
# 3            2.0       2.0       2.0       2.0       NaN       1.0  2744.0
# 4            2.0       2.0       2.0       2.0       NaN       1.0  2585.0
# ...          ...       ...       ...       ...       ...       ...     ...
# 433318       2.0       2.0       7.0       2.0       NaN       1.0  2921.0
# 433319       2.0       2.0       2.0       2.0       NaN       2.0  2496.0
# 433320       2.0       2.0       2.0       2.0       NaN       1.0  3438.0
# 433321       2.0       2.0       2.0       2.0       NaN       1.0  2386.0
# 433322       2.0       2.0       2.0       1.0       1.0       1.0  1794.0
#
#         _BMI5CAT  _RFBMI5  ALCDAY4  GENHLTH  PHYSHLTH  MENTHLTH  CHOLCHK3  \
# 0            4.0        2    888.0      2.0      88.0      88.0       3.0
# 1            3.0        2    888.0      2.0      88.0      88.0       2.0
# 2            2.0        1    888.0      4.0       6.0       2.0       2.0
# 3            3.0        2    888.0      2.0       2.0      88.0       3.0
# 4            3.0        2    202.0      4.0      88.0      88.0       2.0
# ...          ...      ...      ...      ...       ...       ...       ...
# 433318       3.0        2    105.0      3.0      12.0      30.0       2.0
# 433319       2.0        1    888.0      2.0      88.0      88.0       2.0
# 433320       4.0        2    201.0      2.0      10.0      88.0       2.0
# 433321       2.0        1    888.0      3.0      88.0      88.0       2.0
# 433322       1.0        1    220.0      5.0       2.0      88.0       7.0
#
#         CHECKUP1
# 0            2.0
# 1            2.0
# 2            1.0
# 3            3.0
# 4            1.0
# ...          ...
# 433318       1.0
# 433319       1.0
# 433320       1.0
# 433321       1.0
# 433322       7.0
#
# [433323 rows x 23 columns]

# %% [markdown]
# Labels dictionaries for basic value-to-label conversions

# %%
state_labels = {
         1: "Alabama", 2: "Alaska", 4: "Arizona", 5: "Arkansas", 6: "California", 8: "Colorado",
         9: "Connecticut", 10: "Delaware", 11: "District of Columbia", 12: "Florida", 13: "Georgia",
         15: "Hawaii", 16: "Idaho", 17: "Illinois", 18: "Indiana", 19: "Iowa", 20: "Kansas",
         22: "Louisiana", 23: "Maine", 24: "Maryland", 25: "Massachusetts", 26: "Michigan",
         27: "Minnesota", 28: "Mississippi", 29: "Missouri", 30: "Montana", 31: "Nebraska",
         32: "Nevada", 33: "New Hampshire", 34: "New Jersey", 35: "New Mexico", 36: "New York",
         37: "North Carolina", 38: "North Dakota", 39: "Ohio", 40: "Oklahoma", 41: "Oregon",
         44: "Rhode Island", 45: "South Carolina", 46: "South Dakota", 47: "Tennessee", 48: "Texas",
         49: "Utah", 50: "Vermont", 51: "Virginia", 53: "Washington", 54: "West Virginia",
         55: "Wisconsin", 56: "Wyoming", 66: "Guam", 72: "Puerto Rico", 78: "Virgin Islands"
    }

sex_labels = {1: 'Male', 2: 'Female'}

age_labels = {
    1: "18-24", 2: "25-29", 3: "30-34", 4: "35-39",
    5: "40-44", 6: "45-49", 7: "50-54", 8: "55-59",
    9: "60-64", 10: "65-69", 11: "70-74", 12: "75-79", 13: "80+",
    np.nan: None, 14: None
}

edulevel_labels = {
    1: "Never attended school",
    2: "Elementary",
    3: "Some high school",
    4: "High school graduate",
    5: "Some college or technical school",
    6: "College graduate or higher",
    9: "Refused",
    pd.NA: None
}

income_labels = {
    1: "Less than $10,000",
    2: "$10,000 to <$15,000",
    3: "$15,000 to <$20,000",
    4: "$20,000 to <$25,000",
    5: "$25,000 to <$35,000",
    6: "$35,000 to <$50,000",
    7: "$50,000 to <$75,000",
    8: "$75,000 to < $100,000",
    9: "$100,000 to < $150,000",
    10: "$150,000 to < $200,000", 
    11: "$200,000 or more",
    77: None,
    99: None
}

race_labels = {
    1: "White only (non-Hispanic)",
    2: "Black only (non-Hispanic)",
    3: "American Indian/Alaska Native (non-Hispanic)",
    4: "Asian (non-Hispanic)",
    5: "Native Hawaiian or other Pacific Islander only (non-Hispanic)",
    6: "Other race (non-Hispanic)",
    7: "Multiracial (non-Hispanic)",
    8: "Hispanic",
    9: None
}

blood_pressure_labels = {
    1: "Yes",
    2: "Yes, but only during pregnancy",
    3: "No",
    4: "Borderline high",
    7: None,
    9: None
}

diabetes_labels = {
    1: "Yes",
    2: "Yes, but only during pregnancy",
    3: "No",
    4: "Pre-diabetes or borderline diabetes",
    7: None,
    9: None
}

smokday2_labels = {
    1: "Every day",
    2: "Some days",
    3: "Not at all",
    7: None,
    9: None 
}

bmi_labels = {
    1: "Underweight",
    2: "Normal weight",
    3: "Overweight",
    4: "Obese"
}

bmi_binary = {
    1: "No",
    2: "Yes",
    9: None
}

genhealth_labels = {
    1: "Excellent",
    2: "Very good",
    3: "Good",
    4: "Fair",
    5: "Poor",
    7: None,
    9: None
}

cholchk3_labels = {
    1: "Never",
    2: "Within the past year",
    3: "Within the past 2 years",
    4: "Within the past 3 years",
    5: "Within the past 4 years",
    6: "Within the past 5 years",
    7: None,
    8: "5 or more years ago",
    9: None
}

checkup1_labels = {
    1: "Within past year",
    2: "Within past 2 years",
    3: "Within past 5 years",
    4: "5 or more years ago",
    7: None,
    8: "Never",
    9: None
}

#Simple binary that is used in at least two questions
simple_binary = {
    1: "Yes",
    2: "No",
    7: None, 
    9: None
}

# %% [markdown]
# Functions for numerical conversions

# %%
def process_alcday4(value):
    '''
    The survey data has values starting with 1 for weekly data
    (e.g. 102 means 2 days per week), and values starting with 2 for
    monthly data (e.g. 215 means 15 days per month). To standardize, this
    function will ignore leading 1's, 2's and multiply the weekly data by 4
    to approximate the monthly data. 

    Survey data also contains a value of 888 for "no drinks in past 30 days" 
    which will be converted to 0s.
    '''

    try:
        value_int = int(float(value))
        value_str = str(value_int)

        #If value starts with 1 (weekly data)
        if value_str.startswith(str(1)):
            days_per_week = int(value_str[2]) #Select last digit of survey value
            return days_per_week * 4 
        elif value_str.startswith(str(2)):
            days_per_month = int(value_str[1:]) #Ignore first digit (2) and keep days
            return days_per_month 
        elif value == 888:
            return 0 #No drinks at all
        else: 
            return None #treat 777 (Don't know) and 999 (Refused) as NaN values

    except:
        return None #Values of NaN keep as NaN
    

def removes_missing(value):
    '''
    Converts missing values to None and keeps other
    values the same. Useful for PHYSHLTH and MENTHLTH variables
    that are simply raw counts of days. 
    '''
    if value == 88:
        return None
    elif value == 77:
        return None
    elif value == 99:
        return None
    else:
        return value

# %% [markdown]
# Conversions

# %%
brfss["_STATE"] = brfss["_STATE"].replace(state_labels)
brfss['SEXVAR'] = brfss['SEXVAR'].replace(sex_labels)
brfss["_AGEG5YR"] = brfss["_AGEG5YR"].replace(age_labels)
brfss["EDUCA"] = brfss["EDUCA"].replace(edulevel_labels)
brfss["INCOME3"] = brfss["INCOME3"].replace(income_labels)
brfss["_RACE"] = brfss["_RACE"].replace(race_labels)
brfss["BPHIGH6"] = brfss["BPHIGH6"].replace(blood_pressure_labels)
brfss["DIABETE4"] = brfss["DIABETE4"].replace(diabetes_labels)
brfss["CVDINFR4"] = brfss["CVDINFR4"].replace(simple_binary)
brfss["CVDCRHD4"] = brfss["CVDCRHD4"].replace(simple_binary)
brfss["CVDSTRK3"] = brfss["CVDSTRK3"].replace(simple_binary)
brfss["SMOKE100"] = brfss["SMOKE100"].replace(simple_binary)
brfss["SMOKDAY2"] = brfss["SMOKDAY2"].replace(smokday2_labels)
brfss["EXERANY2"] = brfss["EXERANY2"].replace(simple_binary)
brfss['_BMI5'] = brfss['_BMI5'] / 100   #Source data has 2 implied decimal places
brfss["_BMI5CAT"] = brfss["_BMI5CAT"].replace(bmi_labels)
brfss["_RFBMI5"] = brfss["_RFBMI5"].replace(bmi_binary)
brfss["ALCDAY4"] = brfss["ALCDAY4"].apply(process_alcday4)
brfss["GENHLTH"] = brfss["GENHLTH"].replace(genhealth_labels)
brfss["PHYSHLTH"] = brfss["PHYSHLTH"].apply(removes_missing)
brfss["MENTHLTH"] = brfss["MENTHLTH"].apply(removes_missing)
brfss["CHOLCHK3"] = brfss["CHOLCHK3"].replace(cholchk3_labels)
brfss["CHECKUP1"] = brfss["CHECKUP1"].replace(checkup1_labels)

# %%
brfss
# Out:
#                 _STATE  SEXVAR _AGEG5YR                             EDUCA  \
# 0              Alabama  Female      80+  Some college or technical school
# 1              Alabama  Female      80+  Some college or technical school
# 2              Alabama  Female      80+              High school graduate
# 3              Alabama  Female    75-79  Some college or technical school
# 4              Alabama  Female    75-79  Some college or technical school
# ...                ...     ...      ...                               ...
# 433318  Virgin Islands    Male    65-69  Some college or technical school
# 433319  Virgin Islands  Female    30-34        College graduate or higher
# 433320  Virgin Islands  Female    50-54        College graduate or higher
# 433321  Virgin Islands  Female    65-69        College graduate or higher
# 433322  Virgin Islands    Male    45-49                        Elementary
#
#                        INCOME3                      _RACE BPHIGH6 DIABETE4  \
# 0                         None  White only (non-Hispanic)     Yes      Yes
# 1                         None  White only (non-Hispanic)     Yes       No
# 2          $10,000 to <$15,000  Black only (non-Hispanic)     Yes       No
# 3                         None  White only (non-Hispanic)      No       No
# 4          $50,000 to <$75,000  White only (non-Hispanic)     Yes      Yes
# ...                        ...                        ...     ...      ...
# 433318     $25,000 to <$35,000  Black only (non-Hispanic)     Yes       No
# 433319     $35,000 to <$50,000  Black only (non-Hispanic)      No       No
# 433320  $150,000 to < $200,000                   Hispanic      No       No
# 433321     $15,000 to <$20,000  Black only (non-Hispanic)     Yes      Yes
# 433322     $10,000 to <$15,000  Black only (non-Hispanic)      No       No
#
#        CVDINFR4 CVDCRHD4 CVDSTRK3 SMOKE100    SMOKDAY2 EXERANY2  _BMI5  \
# 0            No       No       No       No         NaN       No  30.47
# 1            No       No       No       No         NaN      Yes  28.56
# 2            No       No       No      Yes  Not at all      Yes  22.31
# 3            No       No       No       No         NaN      Yes  27.44
# 4            No       No       No       No         NaN      Yes  25.85
# ...         ...      ...      ...      ...         ...      ...    ...
# 433318       No       No     None       No         NaN      Yes  29.21
# 433319       No       No       No       No         NaN       No  24.96
# 433320       No       No       No       No         NaN      Yes  34.38
# 433321       No       No       No       No         NaN      Yes  23.86
# 433322       No       No       No      Yes   Every day      Yes  17.94
#
#              _BMI5CAT _RFBMI5  ALCDAY4    GENHLTH  PHYSHLTH  MENTHLTH  \
# 0               Obese     Yes      0.0  Very good       NaN       NaN
# 1          Overweight     Yes      0.0  Very good       NaN       NaN
# 2       Normal weight      No      0.0       Fair       6.0       2.0
# 3          Overweight     Yes      0.0  Very good       2.0       NaN
# 4          Overweight     Yes      2.0       Fair       NaN       NaN
# ...               ...     ...      ...        ...       ...       ...
# 433318     Overweight     Yes     20.0       Good      12.0      30.0
# 433319  Normal weight      No      0.0  Very good       NaN       NaN
# 433320          Obese     Yes      1.0  Very good      10.0       NaN
# 433321  Normal weight      No      0.0       Good       NaN       NaN
# 433322    Underweight      No     20.0       Poor       2.0       NaN
#
#                        CHOLCHK3             CHECKUP1
# 0       Within the past 2 years  Within past 2 years
# 1          Within the past year  Within past 2 years
# 2          Within the past year     Within past year
# 3       Within the past 2 years  Within past 5 years
# 4          Within the past year     Within past year
# ...                         ...                  ...
# 433318     Within the past year     Within past year
# 433319     Within the past year     Within past year
# 433320     Within the past year     Within past year
# 433321     Within the past year     Within past year
# 433322                     None                 None
#
# [433323 rows x 23 columns]

# %% [markdown]
# Change columns names

# %%
brfss.rename(columns={
    "_STATE": "state",
    "SEXVAR": "sex",
    "_AGEG5YR": "age",
    "EDUCA": "education",
    "INCOME3": "income",
    "_RACE": "race",
    "BPHIGH6": "high_blood_pressure",
    "DIABETE4": "diabetes",
    "CVDINFR4": "heart_attack",
    "CVDCRHD4": "heart_disease",
    "CVDSTRK3": "stroke",
    "SMOKE100": "smoked_100_cig",
    "SMOKDAY2": "smoking_frequency",
    "EXERANY2": "physical_activity",
    "_BMI5": "bmi",
    "_BMI5CAT": "bmi_cat",
    "_RFBMI5": "overweight",
    "ALCDAY4": "alcohol",
    "GENHLTH": "gen_health",
    "PHYSHLTH": "phys_health",
    "MENTHLTH": "mental_health",
    "CHOLCHK3": "cholesterol_check",
    "CHECKUP1": "routine_checkup"
}, inplace=True)

# %% [markdown]
# Save final csv

# %%
brfss
# Out:
#                  state     sex    age                         education  \
# 0              Alabama  Female    80+  Some college or technical school
# 1              Alabama  Female    80+  Some college or technical school
# 2              Alabama  Female    80+              High school graduate
# 3              Alabama  Female  75-79  Some college or technical school
# 4              Alabama  Female  75-79  Some college or technical school
# ...                ...     ...    ...                               ...
# 433318  Virgin Islands    Male  65-69  Some college or technical school
# 433319  Virgin Islands  Female  30-34        College graduate or higher
# 433320  Virgin Islands  Female  50-54        College graduate or higher
# 433321  Virgin Islands  Female  65-69        College graduate or higher
# 433322  Virgin Islands    Male  45-49                        Elementary
#
#                         income                       race high_blood_pressure  \
# 0                         None  White only (non-Hispanic)                 Yes
# 1                         None  White only (non-Hispanic)                 Yes
# 2          $10,000 to <$15,000  Black only (non-Hispanic)                 Yes
# 3                         None  White only (non-Hispanic)                  No
# 4          $50,000 to <$75,000  White only (non-Hispanic)                 Yes
# ...                        ...                        ...                 ...
# 433318     $25,000 to <$35,000  Black only (non-Hispanic)                 Yes
# 433319     $35,000 to <$50,000  Black only (non-Hispanic)                  No
# 433320  $150,000 to < $200,000                   Hispanic                  No
# 433321     $15,000 to <$20,000  Black only (non-Hispanic)                 Yes
# 433322     $10,000 to <$15,000  Black only (non-Hispanic)                  No
#
#        diabetes heart_attack heart_disease stroke smoked_100_cig  \
# 0           Yes           No            No     No             No
# 1            No           No            No     No             No
# 2            No           No            No     No            Yes
# 3            No           No            No     No             No
# 4           Yes           No            No     No             No
# ...         ...          ...           ...    ...            ...
# 433318       No           No            No   None             No
# 433319       No           No            No     No             No
# 433320       No           No            No     No             No
# 433321      Yes           No            No     No             No
# 433322       No           No            No     No            Yes
#
#        smoking_frequency physical_activity    bmi        bmi_cat overweight  \
# 0                    NaN                No  30.47          Obese        Yes
# 1                    NaN               Yes  28.56     Overweight        Yes
# 2             Not at all               Yes  22.31  Normal weight         No
# 3                    NaN               Yes  27.44     Overweight        Yes
# 4                    NaN               Yes  25.85     Overweight        Yes
# ...                  ...               ...    ...            ...        ...
# 433318               NaN               Yes  29.21     Overweight        Yes
# 433319               NaN                No  24.96  Normal weight         No
# 433320               NaN               Yes  34.38          Obese        Yes
# 433321               NaN               Yes  23.86  Normal weight         No
# 433322         Every day               Yes  17.94    Underweight         No
#
#         alcohol gen_health  phys_health  mental_health  \
# 0           0.0  Very good          NaN            NaN
# 1           0.0  Very good          NaN            NaN
# 2           0.0       Fair          6.0            2.0
# 3           0.0  Very good          2.0            NaN
# 4           2.0       Fair          NaN            NaN
# ...         ...        ...          ...            ...
# 433318     20.0       Good         12.0           30.0
# 433319      0.0  Very good          NaN            NaN
# 433320      1.0  Very good         10.0            NaN
# 433321      0.0       Good          NaN            NaN
# 433322     20.0       Poor          2.0            NaN
#
#               cholesterol_check      routine_checkup
# 0       Within the past 2 years  Within past 2 years
# 1          Within the past year  Within past 2 years
# 2          Within the past year     Within past year
# 3       Within the past 2 years  Within past 5 years
# 4          Within the past year     Within past year
# ...                         ...                  ...
# 433318     Within the past year     Within past year
# 433319     Within the past year     Within past year
# 433320     Within the past year     Within past year
# 433321     Within the past year     Within past year
# 433322                     None                 None
#
# [433323 rows x 23 columns]

# %%
brfss.to_csv("brfss_processed.csv")

# %% [markdown]
# Ensure correct parsing

# %%
saved = pd.read_csv("brfss_processed.csv", index_col=0)
print(brfss.shape)
print(saved.shape)
# Out:
# (433323, 23)
# (433323, 23)

# %%
saved
# Out:
#                  state     sex    age                         education  \
# 0              Alabama  Female    80+  Some college or technical school
# 1              Alabama  Female    80+  Some college or technical school
# 2              Alabama  Female    80+              High school graduate
# 3              Alabama  Female  75-79  Some college or technical school
# 4              Alabama  Female  75-79  Some college or technical school
# ...                ...     ...    ...                               ...
# 433318  Virgin Islands    Male  65-69  Some college or technical school
# 433319  Virgin Islands  Female  30-34        College graduate or higher
# 433320  Virgin Islands  Female  50-54        College graduate or higher
# 433321  Virgin Islands  Female  65-69        College graduate or higher
# 433322  Virgin Islands    Male  45-49                        Elementary
#
#                         income                       race high_blood_pressure  \
# 0                          NaN  White only (non-Hispanic)                 Yes
# 1                          NaN  White only (non-Hispanic)                 Yes
# 2          $10,000 to <$15,000  Black only (non-Hispanic)                 Yes
# 3                          NaN  White only (non-Hispanic)                  No
# 4          $50,000 to <$75,000  White only (non-Hispanic)                 Yes
# ...                        ...                        ...                 ...
# 433318     $25,000 to <$35,000  Black only (non-Hispanic)                 Yes
# 433319     $35,000 to <$50,000  Black only (non-Hispanic)                  No
# 433320  $150,000 to < $200,000                   Hispanic                  No
# 433321     $15,000 to <$20,000  Black only (non-Hispanic)                 Yes
# 433322     $10,000 to <$15,000  Black only (non-Hispanic)                  No
#
#        diabetes heart_attack heart_disease stroke smoked_100_cig  \
# 0           Yes           No            No     No             No
# 1            No           No            No     No             No
# 2            No           No            No     No            Yes
# 3            No           No            No     No             No
# 4           Yes           No            No     No             No
# ...         ...          ...           ...    ...            ...
# 433318       No           No            No    NaN             No
# 433319       No           No            No     No             No
# 433320       No           No            No     No             No
# 433321      Yes           No            No     No             No
# 433322       No           No            No     No            Yes
#
#        smoking_frequency physical_activity    bmi        bmi_cat overweight  \
# 0                    NaN                No  30.47          Obese        Yes
# 1                    NaN               Yes  28.56     Overweight        Yes
# 2             Not at all               Yes  22.31  Normal weight         No
# 3                    NaN               Yes  27.44     Overweight        Yes
# 4                    NaN               Yes  25.85     Overweight        Yes
# ...                  ...               ...    ...            ...        ...
# 433318               NaN               Yes  29.21     Overweight        Yes
# 433319               NaN                No  24.96  Normal weight         No
# 433320               NaN               Yes  34.38          Obese        Yes
# 433321               NaN               Yes  23.86  Normal weight         No
# 433322         Every day               Yes  17.94    Underweight         No
#
#         alcohol gen_health  phys_health  mental_health  \
# 0           0.0  Very good          NaN            NaN
# 1           0.0  Very good          NaN            NaN
# 2           0.0       Fair          6.0            2.0
# 3           0.0  Very good          2.0            NaN
# 4           2.0       Fair          NaN            NaN
# ...         ...        ...          ...            ...
# 433318     20.0       Good         12.0           30.0
# 433319      0.0  Very good          NaN            NaN
# 433320      1.0  Very good         10.0            NaN
# 433321      0.0       Good          NaN            NaN
# 433322     20.0       Poor          2.0            NaN
#
#               cholesterol_check      routine_checkup
# 0       Within the past 2 years  Within past 2 years
# 1          Within the past year  Within past 2 years
# 2          Within the past year     Within past year
# 3       Within the past 2 years  Within past 5 years
# 4          Within the past year     Within past year
# ...                         ...                  ...
# 433318     Within the past year     Within past year
# 433319     Within the past year     Within past year
# 433320     Within the past year     Within past year
# 433321     Within the past year     Within past year
# 433322                      NaN                  NaN
#
# [433323 rows x 23 columns]

# %%
brfss[brfss.heart_attack != brfss.heart_disease]
# Out:
#                  state     sex    age                         education  \
# 21             Alabama    Male    80+              High school graduate
# 23             Alabama    Male  70-74                  Some high school
# 24             Alabama  Female  70-74  Some college or technical school
# 38             Alabama  Female  70-74  Some college or technical school
# 49             Alabama  Female  60-64              High school graduate
# ...                ...     ...    ...                               ...
# 433237  Virgin Islands    Male  75-79                        Elementary
# 433250  Virgin Islands    Male    80+              High school graduate
# 433283  Virgin Islands    Male  40-44              High school graduate
# 433295  Virgin Islands  Female  65-69              High school graduate
# 433316  Virgin Islands    Male  55-59        College graduate or higher
#
#                         income                                          race  \
# 21         $20,000 to <$25,000                     White only (non-Hispanic)
# 23           Less than $10,000                     White only (non-Hispanic)
# 24         $35,000 to <$50,000                     Black only (non-Hispanic)
# 38         $35,000 to <$50,000                     White only (non-Hispanic)
# 49      $150,000 to < $200,000                     White only (non-Hispanic)
# ...                        ...                                           ...
# 433237                    None  American Indian/Alaska Native (non-Hispanic)
# 433250     $15,000 to <$20,000                    Multiracial (non-Hispanic)
# 433283                    None                     Other race (non-Hispanic)
# 433295     $10,000 to <$15,000                                      Hispanic
# 433316  $100,000 to < $150,000                                          None
#
#        high_blood_pressure                             diabetes heart_attack  \
# 21                     Yes                                   No           No
# 23                     Yes                                   No          Yes
# 24                     Yes                                  Yes          Yes
# 38                     Yes                                   No           No
# 49                      No                                  Yes          Yes
# ...                    ...                                  ...          ...
# 433237                 Yes                                   No         None
# 433250                 Yes                                   No          Yes
# 433283                 Yes                                  Yes           No
# 433295                 Yes  Pre-diabetes or borderline diabetes          Yes
# 433316                 Yes                                   No           No
#
#        heart_disease stroke smoked_100_cig smoking_frequency  \
# 21               Yes     No             No               NaN
# 23                No     No            NaN               NaN
# 24                No     No             No               NaN
# 38               Yes     No             No               NaN
# 49                No     No            Yes        Not at all
# ...              ...    ...            ...               ...
# 433237          None     No             No               NaN
# 433250            No     No             No               NaN
# 433283           Yes     No             No               NaN
# 433295            No   None             No               NaN
# 433316           Yes     No            NaN               NaN
#
#        physical_activity    bmi        bmi_cat overweight  alcohol gen_health  \
# 21                   Yes  25.00     Overweight        Yes      0.0  Very good
# 23                   Yes    NaN            NaN       None      NaN       Good
# 24                   Yes  26.63     Overweight        Yes      0.0       Good
# 38                   Yes  30.95          Obese        Yes      0.0       Good
# 49                    No  24.27  Normal weight         No      1.0       Fair
# ...                  ...    ...            ...        ...      ...        ...
# 433237                No  31.47          Obese        Yes      0.0       Good
# 433250                No  19.49  Normal weight         No      3.0       Good
# 433283                No  34.08          Obese        Yes      0.0       Fair
# 433295                No  26.05     Overweight        Yes      0.0       Poor
# 433316               Yes  27.12     Overweight        Yes      NaN  Excellent
#
#         phys_health  mental_health        cholesterol_check   routine_checkup
# 21              NaN            NaN     Within the past year  Within past year
# 23              NaN            NaN     Within the past year  Within past year
# 24              NaN            NaN     Within the past year  Within past year
# 38             10.0            3.0     Within the past year  Within past year
# 49              NaN           30.0     Within the past year  Within past year
# ...             ...            ...                      ...               ...
# 433237         12.0            NaN  Within the past 2 years              None
# 433250          3.0            NaN     Within the past year  Within past year
# 433283          NaN           25.0     Within the past year  Within past year
# 433295          NaN            NaN     Within the past year  Within past year
# 433316          NaN            5.0     Within the past year  Within past year
#
# [30302 rows x 23 columns]
